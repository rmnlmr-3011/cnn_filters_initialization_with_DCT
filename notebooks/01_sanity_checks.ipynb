# %% [markdown]
# Notebook pour vérifier modèle/données/initialisation des filtres

# %% [markdown]
# # 1 Importation des librairies

# %%
import os
import sys
sys.path.append(os.path.abspath(".."))
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# # 2 Importation du dataset cifar10

# %%
from src.data.loaders import load_cifar10, split_train_val

(x_train, y_train), (x_test, y_test) = load_cifar10()
(x_train, y_train), (x_val, y_val) = split_train_val(
    x_train, y_train, val_ratio=0.1, seed=42
)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (45000, 32, 32, 3) (45000,)
# (5000, 32, 32, 3) (5000,)
# (10000, 32, 32, 3) (10000,)

# %% [markdown]
# # 3 Création du modèle

# %% [markdown]
# Entrée du modèle : 32x32x3
# Sortie du modèle : taille 10x1
# Architecture du modèle :
# - convolution 3x3 avec 16 filtres
# - 3 blocs avec 16 filtres
# - 3 blocs avec 32 filtres
# - 3 blocs avec 64 filtres
# - global average pooling
# - dense final => 10 classes

# %%
from src.models.resnet20 import build_resnet20

model = build_resnet20(input_shape=(32, 32, 3), num_classes=10)
model.summary()

model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
# Out:
# Model: "ResNet20"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_63 (Conv2D)             (None, 32, 32, 16)   432         ['input_4[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 32, 32, 16)  64          ['conv2d_63[0][0]']
#  ormalization)
#
#  re_lu_57 (ReLU)                (None, 32, 32, 16)   0           ['batch_normalization_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 32, 32, 16)   2304        ['re_lu_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 32, 32, 16)  64          ['conv2d_64[0][0]']
#  ormalization)
#
#  re_lu_58 (ReLU)                (None, 32, 32, 16)   0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 32, 32, 16)   2304        ['re_lu_58[0][0]']
#
# ...
